# %%
import scanpy as sc
import pandas as pd
import numpy as np
import anndata

# %%
import plotly.graph_objects as go

# %%
p50 = sc.read("/Volumes/kresna-ssd/data/zebrafish/6som_and_imputed/A_50p_imputated_withsphere.h5ad")

# %%
p501
# Out:
# AnnData object with n_obs × n_vars = 8779 × 495
#     obs: 'global_z', 'global_x', 'global_y', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'leiden', 'sphere_z', 'sphere_x', 'sphere_y', 'zcells', 'phi', 'rp', 'clusters'
#     var: 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'mean', 'std'
#     uns: 'leiden', 'leiden_colors', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_raw', 'X_umap', 'global_sphere', 'spatial'
#     varm: 'PCs'
#     layers: 'spliced', 'unspliced'
#     obsp: 'connectivities', 'distances'

# %%
p501.obsm["X_raw"]
# Out:
# array([[  0.        ,   0.        ,   0.        , ...,   3.664631  ,
#           3.664631  ,   3.664631  ],
#        [  0.        ,   6.21258202,   7.10009374, ...,  43.48807416,
#          92.30121862,  36.38798042],
#        [  2.46613799,  25.27791445,  28.97712144, ..., 215.17054006,
#         226.88469553,  23.42831095],
#        ...,
#        [ 34.55589531,  33.17365949,  12.44012231, ..., 174.16171234,
#         176.92618397,  73.25849805],
#        [ 21.31837775,  10.65918888,  14.21225183, ...,  81.72044804,
#          85.273511  ,  39.08369254],
#        [ 27.26700169,  17.35172835,   2.47881834, ...,  71.88573174,
#         121.46209846,  48.33695755]])

# %%
p50
# Out:
# AnnData object with n_obs × n_vars = 8779 × 25118
#     obs: 'global_z', 'global_x', 'global_y', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'leiden', 'clusters', 'timepoint', 'time', 'uniform_density', 'rna_count_based_density'
#     var: 'n_cells', 'sparsity', 'is_training'
#     uns: 'orig.ident2_colors', 'overlap_genes', 'training_genes'
#     obsm: 'global_sphere', 'spatial'

# %%
p50.X
# Out:
# array([[9.46128725e-03, 4.47984461e-06, 4.04760281e-06, ...,
#         8.57104141e-07, 6.92263772e-04, 1.34911600e-05],
#        [4.82223252e-03, 1.08808402e-03, 2.03541523e-05, ...,
#         6.10706735e-07, 3.58432282e-03, 4.15795752e-05],
#        [1.96552034e-03, 2.07052766e-05, 1.40481403e-05, ...,
#         2.44135356e-06, 1.43698648e-02, 2.05837564e-03],
#        ...,
#        [6.55530042e-03, 2.28120792e-05, 4.80859089e-05, ...,
#         1.07971698e-06, 7.01853840e-02, 1.44687270e-04],
#        [1.56982118e-02, 5.67107153e-05, 4.07994720e-06, ...,
#         1.35223021e-06, 5.19528862e-02, 1.06706911e-02],
#        [4.07548746e-05, 1.01390660e-05, 8.75584196e-06, ...,
#         1.44016167e-06, 7.30040098e-03, 3.92703620e-04]])

# %%
p50.obs
# Out:
#                  global_z     global_x     global_y  n_genes  \
# A_50p_3.0       25.027266  1651.599948  1672.517891       38
# A_50p_18.0      73.911905  2069.601094  2027.367576      345
# A_50p_47.0      93.739668  2151.972100  1807.803832      453
# A_50p_58.0      88.098799  2182.407955  2119.047096      399
# A_50p_194.0    108.668681  1953.453007  1975.349429      446
# ...                   ...          ...          ...      ...
# A_50p_23477.0  216.959208  7445.544743  6504.592400      409
# A_50p_23478.0  218.422213  6582.765291  6814.870129      428
# A_50p_23479.0  218.753903  6778.257914  7259.848057      444
# A_50p_23480.0  217.940060  6897.430863  7701.873963      356
# A_50p_23482.0  219.064247  6643.004200  7723.382092      392
#
#                n_genes_by_counts  log1p_n_genes_by_counts  total_counts  \
# A_50p_3.0                     38                 3.663562    164.908395
# A_50p_18.0                   345                 5.846439   3609.510155
# ...

# %%
p50.obsm["global_sphere"][:, 0]
# Out:
# array([-2281.64192473, -2164.22009181, -2097.10049569, ...,
#         1134.23379849,   894.69857579,   725.4900565 ])

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# Example coordinates
x = p50.obsm["global_sphere"][:, 0]
y = p50.obsm["global_sphere"][:, 1]
z = p50.obsm["global_sphere"][:, 2]

# Define angles
angles = [(30, 30), (30, 60), (30, 90), (60, 30), (60, 60), (60, 90)]

for i, (elev, azim) in enumerate(angles, start=1):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')

    ax.scatter(x, y, z)

    ax.view_init(elev=elev, azim=azim)
    ax.set_xlabel('X Label')
    ax.set_ylabel('Y Label')
    ax.set_zlabel('Z Label')


plt.show() # Show the last plot

# %%
# convert adata to df (normalized values)
df = p50.to_df()
# add the obs in the df
df = pd.concat([df, p50.obs], axis=1)

# %%
df
# Out:
#                  ptpn12     phtf2   phtf2.1  cu856344.1  si:zfos-932h1.3  \
# A_50p_3.0      0.009461  0.000004  0.000004    0.000002         0.000040
# A_50p_18.0     0.004822  0.001088  0.000020    0.000005         0.038643
# A_50p_47.0     0.001966  0.000021  0.000014    0.000006         0.000373
# A_50p_58.0     0.011295  0.000373  0.002182    0.000508         0.007834
# A_50p_194.0    0.000072  0.000016  0.000007    0.000415         0.000166
# ...                 ...       ...       ...         ...              ...
# A_50p_23477.0  0.008921  0.000022  0.000007    0.000004         0.002870
# A_50p_23478.0  0.008924  0.001777  0.000006    0.000006         0.004753
# A_50p_23479.0  0.006555  0.000023  0.000048    0.000004         0.000151
# A_50p_23480.0  0.015698  0.000057  0.000004    0.004646         0.032452
# A_50p_23482.0  0.000041  0.000010  0.000009    0.000003         0.000052
#
#                  mansc1      lrp6    dusp16    crebl2     gpr19  ...  \
# ...

# %%
p50
# Out:
# AnnData object with n_obs × n_vars = 8779 × 25118
#     obs: 'global_z', 'global_x', 'global_y', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'leiden', 'clusters', 'timepoint', 'time', 'uniform_density', 'rna_count_based_density'
#     var: 'n_cells', 'sparsity', 'is_training'
#     uns: 'orig.ident2_colors', 'overlap_genes', 'training_genes'
#     obsm: 'global_sphere', 'spatial'

# %%
sc.pl.umap(p50)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 sc.pl.umap(p50)
#
# File ~/DataspellProjects/ptb_timepoints/.conda/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:669, in umap(adata, **kwargs)
#     610 @_wraps_plot_scatter
#     611 @_doc_params(
#     612     adata_color_etc=doc_adata_color_etc,
#    (...)
#     616 )
#     617 def umap(adata, **kwargs) -> Union[Axes, List[Axes], None]:
#     618     """\
#     619     Scatter plot in UMAP basis.
#     620
#    (...)
#     667     tl.umap
#     668     """
# --> 669     return embedding(adata, 'umap', **kwargs)
#
# ...

# %%
p501 = sc.read("/Volumes/kresna-ssd/data/zebrafish/6som_and_imputed/23-08-29__scdata_50p_annotated__3dV7.h5ad")

# %%
p501
# Out:
# AnnData object with n_obs × n_vars = 8779 × 495
#     obs: 'global_z', 'global_x', 'global_y', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'leiden', 'sphere_z', 'sphere_x', 'sphere_y', 'zcells', 'phi', 'rp', 'clusters'
#     var: 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'mean', 'std'
#     uns: 'leiden', 'leiden_colors', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_raw', 'X_umap', 'global_sphere', 'spatial'
#     varm: 'PCs'
#     layers: 'spliced', 'unspliced'
#     obsp: 'connectivities', 'distances'

# %%
p50.obsm["X_umap"] = p501.obsm["X_umap"]

# %%
p50
# Out:
# AnnData object with n_obs × n_vars = 8779 × 25118
#     obs: 'global_z', 'global_x', 'global_y', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'leiden', 'clusters', 'timepoint', 'time', 'uniform_density', 'rna_count_based_density'
#     var: 'n_cells', 'sparsity', 'is_training'
#     uns: 'orig.ident2_colors', 'overlap_genes', 'training_genes'
#     obsm: 'global_sphere', 'spatial', 'X_umap'

# %%
sc.pl.umap(p50, color="clusters",legend_loc="on data")
# Out:
# /Users/kjenie/DataspellProjects/ptb_timepoints/.conda/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
def normalize(df, group, n_groups=1, interval=20):
    largest_delta = 0
    largest_group = f"{group}0"

    for x in range(n_groups):
        print(x)
        min_value = df[f"{group}{x}"].min()
        max_value = df[f"{group}{x}"].max()
        delta = max_value - min_value
        print(delta)
        if delta > largest_delta:
            largest_delta = delta
            largest_group = f"{group}{x}"
        print(largest_delta)

    # Calculate the current min and max values of the global_sphere1 column
    min_value = df[largest_group].min()
    max_value = df[largest_group].max()

    print(largest_group)

    for x in range(n_groups):
        df[f'{group}{x}_norm'] = (df[f"{group}{x}"] - df[f"{group}{x}"].mean()) / (largest_delta/2)

# %%
for x in range(p50.obsm["X_umap"].shape[1]):
    # df[f"X_umap{x}"] = p50.obsm["X_umap"][:,x]
    dfrwarril[f"X_umap{x}"] = p50.obsm["X_umap"][:,x]

# %%
for x in range(p50.obsm["global_sphere"].shape[1]):
    dfrwarril[f"global_sphere{x}"] = p50.obsm["global_sphere"][:,x]

# %%
dfrwarril
# Out:
#             ackr3b    acvr1ba      add3b       adka      ahi1     alcamb  \
# 3.0       0.000000   0.000000   0.000000   3.664631  3.664631   0.000000
# 18.0      0.000000   6.212582   7.100094  12.425164  3.550047   0.887512
# 47.0      2.466138  25.277914  28.977121  17.262966  5.548810   4.315741
# 58.0      1.469163  15.426214  33.790755  19.833704  9.549561   2.938327
# 194.0     0.663402  17.911853  26.536078  19.902058  5.970618   2.653608
# ...            ...        ...        ...        ...       ...        ...
# 23477.0  35.768927  12.624327  10.520273  25.248654  6.312164  18.936491
# 23478.0  28.581371  17.863357   9.527124  26.199591  2.381781  28.581371
# 23479.0  34.555895  33.173659  12.440122   8.293415  5.528943  23.498009
# 23480.0  21.318378  10.659189  14.212252  21.318378  0.000000  14.212252
# 23482.0  27.267002  17.351728   2.478818  19.830547  0.000000   4.957637
#
#              aplnra    aplnrb      hesx1  arl6ip5a  ...    sphere_y  \
# ...

# %%
normalize(dfrwarril, "X_umap", n_groups=p50.obsm["X_umap"].shape[1])
# Out:
# 0
# 21.923588
# 21.923588
# 1
# 18.53732
# 21.923588
# X_umap0

# %%
dfrwarril
# Out:
#             ackr3b    acvr1ba      add3b       adka      ahi1     alcamb  \
# 3.0       0.000000   0.000000   0.000000   3.664631  3.664631   0.000000
# 18.0      0.000000   6.212582   7.100094  12.425164  3.550047   0.887512
# 47.0      2.466138  25.277914  28.977121  17.262966  5.548810   4.315741
# 58.0      1.469163  15.426214  33.790755  19.833704  9.549561   2.938327
# 194.0     0.663402  17.911853  26.536078  19.902058  5.970618   2.653608
# ...            ...        ...        ...        ...       ...        ...
# 23477.0  35.768927  12.624327  10.520273  25.248654  6.312164  18.936491
# 23478.0  28.581371  17.863357   9.527124  26.199591  2.381781  28.581371
# 23479.0  34.555895  33.173659  12.440122   8.293415  5.528943  23.498009
# 23480.0  21.318378  10.659189  14.212252  21.318378  0.000000  14.212252
# 23482.0  27.267002  17.351728   2.478818  19.830547  0.000000   4.957637
#
#              aplnra    aplnrb      hesx1  arl6ip5a  ...       phi          rp  \
# ...

# %%
plt.clf()

# %%
import matplotlib.pyplot as plt
import numpy as np


plt.scatter(df["X_umap0_norm"], df["X_umap1_norm"])
# plt.scatter(df["X_umap0"], df["X_umap1"])
plt.title('Sample Scatter Plot')
plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()


plt.scatter(dfrwarril["global_sphere0"], dfrwarril["global_sphere1"], dfrwarril["global_sphere2"])
# plt.scatter(df["X_umap0"], df["X_umap1"])
plt.title('Sample Scatter Plot')
plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')
plt.show()
# Out:
# /Users/kjenie/DataspellProjects/ptb_timepoints/.conda/lib/python3.10/site-packages/matplotlib/collections.py:963: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
normalize(dfrwarril, "global_sphere", n_groups=p50.obsm["global_sphere"].shape[1])
# Out:
# 0
# 5827.303587417723
# 5827.303587417723
# 1
# 4555.7679022056445
# 5827.303587417723
# 2
# 5838.787610515183
# 5838.787610515183
# global_sphere2

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.clf()


plt.scatter(dfrwarril["global_sphere0_norm"], dfrwarril["global_sphere1_norm"], dfrwarril["global_sphere2_norm"])
# plt.scatter(df["X_umap0"], df["X_umap1"])
plt.title('Sample Scatter Plot')
plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')
plt.show()
# Out:
# /Users/kjenie/DataspellProjects/ptb_timepoints/.conda/lib/python3.10/site-packages/matplotlib/collections.py:963: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# Example coordinates
x = df["global_sphere0_norm"]
y = df["global_sphere1_norm"]
z = df["global_sphere2_norm"]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(x, y, z)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')


plt.show() # Show the last plot

# %%
df
# Out:
#                  ptpn12     phtf2   phtf2.1  cu856344.1  si:zfos-932h1.3  \
# A_50p_3.0      0.009461  0.000004  0.000004    0.000002         0.000040
# A_50p_18.0     0.004822  0.001088  0.000020    0.000005         0.038643
# A_50p_47.0     0.001966  0.000021  0.000014    0.000006         0.000373
# A_50p_58.0     0.011295  0.000373  0.002182    0.000508         0.007834
# A_50p_194.0    0.000072  0.000016  0.000007    0.000415         0.000166
# ...                 ...       ...       ...         ...              ...
# A_50p_23477.0  0.008921  0.000022  0.000007    0.000004         0.002870
# A_50p_23478.0  0.008924  0.001777  0.000006    0.000006         0.004753
# A_50p_23479.0  0.006555  0.000023  0.000048    0.000004         0.000151
# A_50p_23480.0  0.015698  0.000057  0.000004    0.004646         0.032452
# A_50p_23482.0  0.000041  0.000010  0.000009    0.000003         0.000052
#
#                  mansc1      lrp6    dusp16    crebl2     gpr19  ...  \
# ...

# %%
print(p50.raw)
# Out:
# None

# %%
p501
# Out:
# AnnData object with n_obs × n_vars = 8779 × 495
#     obs: 'global_z', 'global_x', 'global_y', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'leiden', 'sphere_z', 'sphere_x', 'sphere_y', 'zcells', 'phi', 'rp', 'clusters'
#     var: 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'mean', 'std'
#     uns: 'leiden', 'leiden_colors', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_raw', 'X_umap', 'global_sphere', 'spatial'
#     varm: 'PCs'
#     layers: 'spliced', 'unspliced'
#     obsp: 'connectivities', 'distances'

# %%
from tqdm import tqdm
import json

# %%
df.columns
# Out:
# Index(['ptpn12', 'phtf2', 'phtf2.1', 'cu856344.1', 'si:zfos-932h1.3', 'mansc1',
#        'lrp6', 'dusp16', 'crebl2', 'gpr19',
#        ...
#        'X_umap0', 'X_umap1', 'global_sphere0', 'global_sphere1',
#        'global_sphere2', 'X_umap0_norm', 'X_umap1_norm', 'global_sphere0_norm',
#        'global_sphere1_norm', 'global_sphere2_norm'],
#       dtype='object', length=25142)

# %%
prefix="p50"

# %%
gene_raw = p501.var_names

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
json.dumps(df[col].to_list())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 json.dumps(df[col].to_list())
#
# NameError: name 'col' is not defined

# %%
import requests


url = 'https://fisheyes.techkyra.com/savedata'
# data = {'key': 'test', 'value': "dd"}

# response = requests.post(url, json=data)
# print(response.json())

# %%
"ptpn12" in gene_raw
# Out:
# False

# %%
prefix = "50pe"

# %%
df
# Out:
#                  ptpn12     phtf2   phtf2.1  cu856344.1  si:zfos-932h1.3  \
# A_50p_3.0      0.009461  0.000004  0.000004    0.000002         0.000040
# A_50p_18.0     0.004822  0.001088  0.000020    0.000005         0.038643
# A_50p_47.0     0.001966  0.000021  0.000014    0.000006         0.000373
# A_50p_58.0     0.011295  0.000373  0.002182    0.000508         0.007834
# A_50p_194.0    0.000072  0.000016  0.000007    0.000415         0.000166
# ...                 ...       ...       ...         ...              ...
# A_50p_23477.0  0.008921  0.000022  0.000007    0.000004         0.002870
# A_50p_23478.0  0.008924  0.001777  0.000006    0.000006         0.004753
# A_50p_23479.0  0.006555  0.000023  0.000048    0.000004         0.000151
# A_50p_23480.0  0.015698  0.000057  0.000004    0.004646         0.032452
# A_50p_23482.0  0.000041  0.000010  0.000009    0.000003         0.000052
#
#                  mansc1      lrp6    dusp16    crebl2     gpr19  ...  \
# ...

# %%
dfraw = pd.DataFrame(p501.obsm["X_raw"], columns=p501.to_df().columns, index=p501.obs.index)

# %%
dfrwarril = pd.concat([dfraw, p501.obs], axis=1)

# %%
a = [2, 3, -5, 9, -4]

# %%
import statistics

# %%
statistics.stdev(a)
# Out:
# 5.70087712549569

# %%
import numpy as np
from scipy import stats

# Your data
a = [2, 3, -5, 9, -4]

# Mean of the data
mean = np.mean(a)

# Standard error of the mean (SEM)
sem = stats.sem(a)

# Size of the data
n = len(a)

# Degrees of freedom
df = n - 1

# Confidence level
confidence = 0.99

# Compute the 99% confidence interval
ci = stats.t.interval(confidence, df, mean, sem)

print(f"99% confidence interval: {ci}")
# Out:
# 99% confidence interval: (-10.73818479589106, 12.73818479589106)

# %%
dfrwarril
# Out:
#             ackr3b    acvr1ba      add3b       adka      ahi1     alcamb  \
# 3.0       0.000000   0.000000   0.000000   3.664631  3.664631   0.000000
# 18.0      0.000000   6.212582   7.100094  12.425164  3.550047   0.887512
# 47.0      2.466138  25.277914  28.977121  17.262966  5.548810   4.315741
# 58.0      1.469163  15.426214  33.790755  19.833704  9.549561   2.938327
# 194.0     0.663402  17.911853  26.536078  19.902058  5.970618   2.653608
# ...            ...        ...        ...        ...       ...        ...
# 23477.0  35.768927  12.624327  10.520273  25.248654  6.312164  18.936491
# 23478.0  28.581371  17.863357   9.527124  26.199591  2.381781  28.581371
# 23479.0  34.555895  33.173659  12.440122   8.293415  5.528943  23.498009
# 23480.0  21.318378  10.659189  14.212252  21.318378  0.000000  14.212252
# 23482.0  27.267002  17.351728   2.478818  19.830547  0.000000   4.957637
#
#              aplnra    aplnrb      hesx1  arl6ip5a  ...   X_umap0    X_umap1  \
# ...

# %%
for c in df.columns.tolist():
    print(c)
# Out:
# ptpn12
# phtf2
# phtf2.1
# cu856344.1
# si:zfos-932h1.3
# mansc1
# lrp6
# dusp16
# crebl2
# gpr19
# tbk1
# eps8a
# ptpro
# ptpro.1
# rerg
# si:ch73-252i11.1
# cabz01085275.1
# echdc3
# fo834823.1
# msgn1
# si:ch211-51e12.7
# mrps10
# tulp4a
# tmem181
# dynlt1
# rpl18a
# bx890562.3
# bx890562.2
# pthlha
# xpot
# rtcb
# cu855889.1
# fbxo7
# cu855889.2
# ost4
# agbl5
# tmem214
# mapre3b
# dpysl5b
# sobpb
# si:ch211-152c2.3
# crybg1b
# bx649468.1
# mrap2b
# ripply2
# sim1b
# atp23
# rpap3
# naga
# fam180a
# mtpn
# si:ch211-117i20.2
# chrm2a
# ptn
# cabz01068469.1
# zmp:0000000711
# slc38a4
# al929171.1
# slc38a2
# scaf11
# arid2
# cr847994.1
# gas2l3
# fgfr1op2
# tm7sf3
# med21
# pmpcb
# dnajc2
# nudt4b
# ube2nb
# mrpl42
# pwp1
# cu571163.1
# ano6
# si:ch73-177h5.2
# far2
# cpsf6
# yeats4
# kcnc2
# frs2a
# si:ch73-278m9.1
# cmah
# glipr1a
# krr1
# si:ch73-89b15.3
# phlda1
# nap1l1
# osbpl8
# zdhhc17
# csrp2
# e2f7
# cog5
# gpr22a
# dus4l
# bcap29
# slco1c1
# pde3a
# aebp2
# plekha5
# ...

# %%
df.columns.tolist()[5867:]
# Out:
# ['slc15a1b',
#  'dock9b',
#  'bmpr2a',
#  'fam117ba',
#  'ical1',
#  'cu639412.1',
#  'cxcr4a',
#  'mcm6',
#  'si:ch73-71c20.5',
#  'tmbim1a',
#  'pnkd',
#  'catip',
#  'casp8',
#  'l3hypdh',
#  'casp20',
#  'dytn',
#  'adam23a',
#  'eef1b2',
#  'ct009620.1',
#  'ndufs1',
#  'ino80db',
#  'kcnj3b',
#  'rprmb',
#  'arl6ip6',
#  'fmnl2b',
#  'mylkb',
#  'gmppab',
#  'asic4b',
#  'chpfb',
#  'wnt6a',
#  'tmem198b',
#  'desmb',
#  'dnpep',
#  'ptprnb',
#  'gca',
#  'etv5b',
#  'cacnb4b',
#  'inpp4ab',
#  'tmem182b',
#  'cr407585.1',
#  'pou3f3b',
#  'mrps9',
#  'tgfbrap1',
#  'fhl2b',
#  'dph3',
#  'nck2b',
#  'ecrg4b',
#  'cu468896.1',
#  'tmtops2a',
#  'st6gal2b',
#  'lrrfip1b',
#  'mlpha',
#  'trim63a',
#  'ackr3b',
#  'iqca1',
#  'cr759882.1',
#  'cr847983.1',
#  'cr847983.2',
#  'gbx2',
#  'agap1',
#  'cr854926.1',
#  'faimb',
#  'ccdc80l1',
#  'slc19a2',
#  'zgc:161969',
#  'psmb3',
#  'si:ch73-193c12.2',
#  'unc80',
#  'nomo',
#  'cr762392.1',
#  'pimr5',
#  'bx511311.3',
# ...

# %%
colsss = df.columns[a:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 colsss = df.columns[a:]
#
# NameError: name 'a' is not defined

# %%
scols = df.columns[a:a+1000]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 scols = df.columns[a:a+1000]
#
# NameError: name 'a' is not defined

# %%
scols
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 scols
#
# NameError: name 'scols' is not defined

# %%
colsss
# Out:
# Index(['prpf4ba', 'si:dkey-154p10.3', 'pxdc1a', 'opn4.1', 'tmem53',
#        'bx323807.1', 'bx323807.2', 'bx294160.1', 'rnf220a', 'klf17',
#        ...
#        'X_umap0', 'X_umap1', 'global_sphere0', 'global_sphere1',
#        'global_sphere2', 'X_umap0_norm', 'X_umap1_norm', 'global_sphere0_norm',
#        'global_sphere1_norm', 'global_sphere2_norm'],
#       dtype='object', length=17839)

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed
import json
import requests
from tqdm import tqdm
import numpy as np

# Assuming df is your DataFrame and prefix, gene_raw, and url are defined elsewhere
n_splits = 2  # Number of parts to split the DataFrame into
prefix = "50pe"
# Function to upload a portion of the DataFrame
def upload_data(start_idx, end_idx):
    results = []
    for col in dfrwarril[start_idx:end_idx]:
        data = {'key': f"{prefix}-{col}", 'value': json.dumps(dfrwarril[col].to_list())}
        
        response = requests.post(url, json=data)
        results.append(response.json())
    return results

# Split the DataFrame into indices for n_splits
split_indices = np.array_split(np.arange(len(dfrwarril)), n_splits)

# Use ThreadPoolExecutor to upload each part of the DataFrame in parallel
with ThreadPoolExecutor(max_workers=n_splits) as executor:
    futures = [executor.submit(upload_data, start_idx[0], start_idx[-1]+1) for start_idx in split_indices]

    # Progress bar setup
    progress = tqdm(as_completed(futures), total=len(futures))
    
    for future in progress:
        result = future.result()  # This will block until the future is complete
        print(result)  # Or handle the result as needed

# Adjust the implementation details as necessary for your specific requirements
# Out:
# ...
#  50%|█████     | 1/2 [03:49<03:49, 229.82s/it]
# ...

# %%
dfrwarril.iloc[:,-5:]
# Out:
#          X_umap0_norm  X_umap1_norm  global_sphere0_norm  global_sphere1_norm  \
# 3.0          0.967759     -0.492598            -0.765640            -0.462698
# 18.0        -0.499025      0.222094            -0.725418            -0.259404
# 47.0        -0.118277     -0.551456            -0.702427            -0.300519
# 58.0        -0.472522      0.243863            -0.707767            -0.204287
# 194.0       -0.100545     -0.444252            -0.757696            -0.297960
# ...               ...           ...                  ...                  ...
# 23477.0      0.736753      0.774542             0.666805            -0.475318
# 23478.0      0.843155      0.787088             0.466098            -0.248692
# 23479.0      0.716693      0.780309             0.404424            -0.400392
# 23480.0      0.700781      0.777974             0.322374            -0.535399
# 23482.0      0.720096      0.787353             0.264414            -0.468684
#
#          global_sphere2_norm
# ...

# %%
for col in dfrwarril.iloc[:,-5:]:
    data = {'key': f"{prefix}-{col}", 'value': json.dumps(dfrwarril[col].to_list())}
    
    response = requests.post(url, json=data)

# %%
a = 7303

# %%
df.columns.tolist()[-100:]
# Out:
# ['mphosph6',
#  'snx20',
#  'sall1b',
#  'rbl2',
#  'rpgrip1l',
#  'cabz01089081.1',
#  'irx5b',
#  'amfra',
#  'nfatc3b',
#  'dus2',
#  'slc7a10b',
#  'cr354435.3',
#  'faap24',
#  'bmb',
#  'hist1h4l.17',
#  'hist1h2a3.3',
#  'cr354435.2',
#  'hist1h4l.18',
#  'si:ch211-113a14.11',
#  'hist1h4l.19',
#  'si:ch211-113a14.12',
#  'hist1h2a4',
#  'zgc:173552.4',
#  'hist1h4l.20',
#  'zgc:171759.4',
#  'hist1h2a1',
#  'hist1h4l.21',
#  'si:ch211-113a14.18',
#  'si:ch211-113a14.19.3',
#  'zgc:173552.5',
#  'hist1h4l.22',
#  'si:ch211-113a14.22.1',
#  'hist1h2a3.4',
#  'zgc:173552.6',
#  'si:ch211-113a14.22.2',
#  'hist1h4l.23',
#  'zgc:173552.7',
#  'si:ch211-113a14.19.4',
#  'si:ch211-113a14.24',
#  'cr354435.1',
#  'ankrd27',
#  'irx3b',
#  'mafb',
#  'cu929365.2',
#  'wwox',
#  'hprt1l',
#  'nfat5a',
#  'si:ch1073-174d20.1',
#  'si:ch1073-174d20.2',
#  'tdrd12',
#  'urahb',
#  'si:dkey-234i14.2',
#  'si:dkey-234i14.3',
#  'glg1a',
#  'rfwd3',
#  'si:dkey-234i14.6',
#  'nudt7',
# ...

# %%
# save to redis norm + obs + umap + spatial
for col in tqdm(df.columns.tolist()[-100:]):
    print(col)
    print()
    if (col not in gene_raw):
        data = {'key': f"{prefix}-{col}", 'value': json.dumps(df[col].to_list())}
        response = requests.post(url, json=data)
        print(response.json())
    else:
        data = {'key': f"{prefix}-{col}", 'value': json.dumps(dfraw[col].to_list())}
        response = requests.post(url, json=data)
        print(response.json())
    # re.save_to_redis(col, str(df[col].to_list()))
    # re.save_to_redis(f"{prefix}-{col}", json.dumps(df[col].to_list()))
    # break
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# mphosph6
#   1%|          | 1/100 [00:00<00:28,  3.51it/s]
# {'message': 'Data saved to Redis under key: 50pe-mphosph6'}
# snx20
#   2%|▏         | 2/100 [00:00<00:27,  3.50it/s]
# {'message': 'Data saved to Redis under key: 50pe-snx20'}
# sall1b
#   3%|▎         | 3/100 [00:00<00:27,  3.55it/s]
# {'message': 'Data saved to Redis under key: 50pe-sall1b'}
# rbl2
#   4%|▍         | 4/100 [00:01<00:26,  3.64it/s]
# {'message': 'Data saved to Redis under key: 50pe-rbl2'}
# rpgrip1l
#   5%|▌         | 5/100 [00:01<00:25,  3.70it/s]
# {'message': 'Data saved to Redis under key: 50pe-rpgrip1l'}
# cabz01089081.1
#   6%|▌         | 6/100 [00:01<00:28,  3.30it/s]
# {'message': 'Data saved to Redis under key: 50pe-cabz01089081.1'}
# irx5b
#   7%|▋         | 7/100 [00:02<00:29,  3.19it/s]
# {'message': 'Data saved to Redis under key: 50pe-irx5b'}
# amfra
#   8%|▊         | 8/100 [00:02<00:28,  3.25it/s]
# ...

# %%
df.columns.tolist()[-100:-24]
# Out:
# ['mphosph6',
#  'snx20',
#  'sall1b',
#  'rbl2',
#  'rpgrip1l',
#  'cabz01089081.1',
#  'irx5b',
#  'amfra',
#  'nfatc3b',
#  'dus2',
#  'slc7a10b',
#  'cr354435.3',
#  'faap24',
#  'bmb',
#  'hist1h4l.17',
#  'hist1h2a3.3',
#  'cr354435.2',
#  'hist1h4l.18',
#  'si:ch211-113a14.11',
#  'hist1h4l.19',
#  'si:ch211-113a14.12',
#  'hist1h2a4',
#  'zgc:173552.4',
#  'hist1h4l.20',
#  'zgc:171759.4',
#  'hist1h2a1',
#  'hist1h4l.21',
#  'si:ch211-113a14.18',
#  'si:ch211-113a14.19.3',
#  'zgc:173552.5',
#  'hist1h4l.22',
#  'si:ch211-113a14.22.1',
#  'hist1h2a3.4',
#  'zgc:173552.6',
#  'si:ch211-113a14.22.2',
#  'hist1h4l.23',
#  'zgc:173552.7',
#  'si:ch211-113a14.19.4',
#  'si:ch211-113a14.24',
#  'cr354435.1',
#  'ankrd27',
#  'irx3b',
#  'mafb',
#  'cu929365.2',
#  'wwox',
#  'hprt1l',
#  'nfat5a',
#  'si:ch1073-174d20.1',
#  'si:ch1073-174d20.2',
#  'tdrd12',
#  'urahb',
#  'si:dkey-234i14.2',
#  'si:dkey-234i14.3',
#  'glg1a',
#  'rfwd3',
#  'si:dkey-234i14.6',
#  'nudt7',
# ...

# %%
a
# Out:
# 8222

# %%
df.columns.tolist()[7525]
# Out:
# 'ftr12.1'

# %%
gene_raw.tolist()
# Out:
# ['ackr3b',
#  'acvr1ba',
#  'add3b',
#  'adka',
#  'ahi1',
#  'alcamb',
#  'aplnra',
#  'aplnrb',
#  'hesx1',
#  'arl6ip5a',
#  'aspm',
#  'atf6',
#  'axin2',
#  'bambia',
#  'bhlha15',
#  'bmp2b',
#  'bmp7a',
#  'btg2',
#  'tbx3b',
#  'c1qbp',
#  'zmp:0000000624',
#  'ca9',
#  'casz1',
#  'cbx3a',
#  'cbx5',
#  'ccne2',
#  'ccng1',
#  'cd63',
#  'cdc14b',
#  'cdc42ep4a',
#  'cdca8',
#  'cdh1',
#  'cenpf',
#  'cfl1l',
#  'chst11',
#  'cldnd',
#  'clic4',
#  'clocka',
#  'cnn3a',
#  'crabp2b',
#  'creb3l2',
#  'cst3',
#  'cth1',
#  'cxcr4a',
#  'dact2',
#  'dharma',
#  'dkc1',
#  'dlgap5',
#  'dlx3b',
#  'dynll2b',
#  'efemp2b',
#  'efnb2b',
#  'egln1b',
#  'elavl3',
#  'emid1',
#  'emx3',
#  'epha2a',
#  'ephb3a',
#  'esrra',
#  'etv4',
#  'etv5a',
#  'eve1',
#  'f11r.1',
#  'lratd1',
#  'fbln2',
#  'zgc:175088',
#  'fgf8a',
#  'flrt3',
#  'fn1a',
#  'fn1b',
#  'fnbp1l',
#  'foxa2',
#  'foxa3',
#  'foxc1b',
#  'foxd3',
#  'foxn2b',
#  'foxp1b',
#  'fscn1a',
#  'fzd7b',
#  'fzd8a',
# ...

# %%
genes_so_far =  gene_raw.tolist()

# %%
len(genes_so_far)
# Out:
# 495

# %%
data = {'key': f"{prefix}-genes", 'value': json.dumps(genes_so_far)}
response = requests.post(url, json=data)
print(response.json())
# Out:
# {'message': 'Data saved to Redis under key: 50pe-genes'}

# %%
a
# Out:
# 8243

# %%
df.columns.tolist()[8222]
# Out:
# 'tmem131l'

# %%
gene_raw
# Out:
# Index(['ackr3b', 'acvr1ba', 'add3b', 'adka', 'ahi1', 'alcamb', 'aplnra',
#        'aplnrb', 'hesx1', 'arl6ip5a',
#        ...
#        'rplp0', 'nasp', 'rplp2l', 'nop58', 'rps6', 'rbm4.3', 'sox32', 'tbx16',
#        'tuba8l4', 'xbp1'],
#       dtype='object', length=495)

# %%
# save to redis norm + obs + umap + spatial
for col in gene_raw:
    print(col)
    data = {'key': f"{prefix}-{col}", 'value': json.dumps(dfraw[col].to_list())}
    response = requests.post(url, json=data)
    print(response.json())
    # re.save_to_redis(col, str(df[col].to_list()))
    # re.save_to_redis(f"{prefix}-{col}", json.dumps(df[col].to_list()))
    # break
# Out:
# ackr3b
# {'message': 'Data saved to Redis under key: 50pe-ackr3b'}
# acvr1ba
# {'message': 'Data saved to Redis under key: 50pe-acvr1ba'}
# add3b
# {'message': 'Data saved to Redis under key: 50pe-add3b'}
# adka
# {'message': 'Data saved to Redis under key: 50pe-adka'}
# ahi1
# {'message': 'Data saved to Redis under key: 50pe-ahi1'}
# alcamb
# {'message': 'Data saved to Redis under key: 50pe-alcamb'}
# aplnra
# {'message': 'Data saved to Redis under key: 50pe-aplnra'}
# aplnrb
# {'message': 'Data saved to Redis under key: 50pe-aplnrb'}
# hesx1
# {'message': 'Data saved to Redis under key: 50pe-hesx1'}
# arl6ip5a
# {'message': 'Data saved to Redis under key: 50pe-arl6ip5a'}
# aspm
# {'message': 'Data saved to Redis under key: 50pe-aspm'}
# atf6
# {'message': 'Data saved to Redis under key: 50pe-atf6'}
# axin2
# {'message': 'Data saved to Redis under key: 50pe-axin2'}
# bambia
# {'message': 'Data saved to Redis under key: 50pe-bambia'}
# bhlha15
# ...

# %%
a
# Out:
# 8222

# %%
dfraw
# Out:
#             ackr3b    acvr1ba      add3b       adka      ahi1     alcamb  \
# 3.0       0.000000   0.000000   0.000000   3.664631  3.664631   0.000000
# 18.0      0.000000   6.212582   7.100094  12.425164  3.550047   0.887512
# 47.0      2.466138  25.277914  28.977121  17.262966  5.548810   4.315741
# 58.0      1.469163  15.426214  33.790755  19.833704  9.549561   2.938327
# 194.0     0.663402  17.911853  26.536078  19.902058  5.970618   2.653608
# ...            ...        ...        ...        ...       ...        ...
# 23477.0  35.768927  12.624327  10.520273  25.248654  6.312164  18.936491
# 23478.0  28.581371  17.863357   9.527124  26.199591  2.381781  28.581371
# 23479.0  34.555895  33.173659  12.440122   8.293415  5.528943  23.498009
# 23480.0  21.318378  10.659189  14.212252  21.318378  0.000000  14.212252
# 23482.0  27.267002  17.351728   2.478818  19.830547  0.000000   4.957637
#
#              aplnra    aplnrb      hesx1  arl6ip5a  ...      rplp0       nasp  \
# ...

# %%
# save to redis norm + obs + umap + spatial
a= 7525
for col in tqdm(df.columns.tolist()[7525:]):
    print(col)
    print()
    if (col not in gene_raw):
        data = {'key': f"{prefix}-{col}", 'value': json.dumps(df[col].to_list())}
        response = requests.post(url, json=data)
        print(response.json())
    else:
        data = {'key': f"{prefix}-{col}", 'value': json.dumps(dfraw[col].to_list())}
        response = requests.post(url, json=data)
        print(response.json())
    a += 1
    # re.save_to_redis(col, str(df[col].to_list()))
    # re.save_to_redis(f"{prefix}-{col}", json.dumps(df[col].to_list()))
    # break
# Out:
#   0%|          | 0/17617 [00:00<?, ?it/s]
# ftr12.1
#   0%|          | 1/17617 [00:00<2:28:42,  1.97it/s]
# {'message': 'Data saved to Redis under key: 50pe-ftr12.1'}
# crema
#   0%|          | 2/17617 [00:00<2:06:55,  2.31it/s]
# {'message': 'Data saved to Redis under key: 50pe-crema'}
# pard3ab
#   0%|          | 3/17617 [00:01<2:08:13,  2.29it/s]
# {'message': 'Data saved to Redis under key: 50pe-pard3ab'}
# nrp1b
#   0%|          | 4/17617 [00:01<2:07:38,  2.30it/s]
# {'message': 'Data saved to Redis under key: 50pe-nrp1b'}
# cabz01058723.1
#   0%|          | 5/17617 [00:02<2:08:55,  2.28it/s]
# {'message': 'Data saved to Redis under key: 50pe-cabz01058723.1'}
# cabz01058721.1
#   0%|          | 6/17617 [00:02<2:08:34,  2.28it/s]
# {'message': 'Data saved to Redis under key: 50pe-cabz01058721.1'}
# itgb1b
#   0%|          | 7/17617 [00:03<2:01:04,  2.42it/s]
# {'message': 'Data saved to Redis under key: 50pe-itgb1b'}
# epc1b
#   0%|          | 8/17617 [00:03<2:04:23,  2.36it/s]
# ...

# %%
data
# Out:
# {'key': 'p50-ptpn12',
# ...

# %%
p501
# Out:
# AnnData object with n_obs × n_vars = 8779 × 495
#     obs: 'global_z', 'global_x', 'global_y', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'leiden', 'sphere_z', 'sphere_x', 'sphere_y', 'zcells', 'phi', 'rp', 'clusters'
#     var: 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'mean', 'std'
#     uns: 'leiden', 'leiden_colors', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_raw', 'X_umap', 'global_sphere', 'spatial'
#     varm: 'PCs'
#     layers: 'spliced', 'unspliced'
#     obsp: 'connectivities', 'distances'

# %%
p501
# Out:
# AnnData object with n_obs × n_vars = 8779 × 495
#     obs: 'global_z', 'global_x', 'global_y', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'leiden', 'sphere_z', 'sphere_x', 'sphere_y', 'zcells', 'phi', 'rp', 'clusters'
#     var: 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'mean', 'std'
#     uns: 'leiden', 'leiden_colors', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_raw', 'X_umap', 'global_sphere', 'spatial'
#     varm: 'PCs'
#     layers: 'spliced', 'unspliced'
#     obsp: 'connectivities', 'distances'

# %%
adata = p501

# convert adata to df (normalized values)
# df = adata.to_df()

df = pd.DataFrame(adata.obsm["X_raw"], columns=adata.to_df().columns, index=adata.obs.index)

# add the obs in the df
df = pd.concat([df, adata.obs], axis=1)

# add the brain projection coordinates in the df
for x in range(adata.obsm["global_sphere"].shape[1]):
    df[f"global_sphere{x}"] = adata.obsm["global_sphere"][:,x]

# add the umap coordinates in the df
# iterate through all axis if there's more than 2, it accounts for it
for x in range(adata.obsm["X_umap"].shape[1]):
    df[f"X_umap{x}"] = adata.obsm["X_umap"][:,x]

normalize(df, "global_sphere", n_groups=adata.obsm["global_sphere"].shape[1])
normalize(df, "X_umap", n_groups=adata.obsm["X_umap"].shape[1])


# save to redis norm + obs + umap + spatial
# for col in tqdm(df):
#     print(col)
#     print()
#     # re.save_to_redis(col, str(df[col].to_list()))
#     re.save_to_redis(f"{prefix}-{col}", json.dumps(df[col].to_list()))
    # break

# # convert adata to df (raw values)
# df = pd.DataFrame(adata.obsm["X_raw"], columns=adata.to_df().columns, index=adata.obs.index)

# # save to redis raw
# for col in tqdm(df):
#     re.save_to_redis(f"{prefix}-{col}_raw", json.dumps(df[col].to_list()))
#     # break


# # also save the uns for coloring purposes
# re.save_to_redis("uns", str(adata.uns))
# return df
# Out:
# 0
# 5827.303587417723
# 5827.303587417723
# 1
# 4555.7679022056445
# 5827.303587417723
# 2
# 5838.787610515183
# 5838.787610515183
# global_sphere2
# 0
# 21.923588
# 21.923588
# 1
# 18.53732
# 21.923588
# X_umap0

# %%
p501
# Out:
# AnnData object with n_obs × n_vars = 8779 × 495
#     obs: 'global_z', 'global_x', 'global_y', 'n_genes', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'leiden', 'sphere_z', 'sphere_x', 'sphere_y', 'zcells', 'phi', 'rp', 'clusters'
#     var: 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'mean', 'std'
#     uns: 'leiden', 'leiden_colors', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_raw', 'X_umap', 'global_sphere', 'spatial'
#     varm: 'PCs'
#     layers: 'spliced', 'unspliced'
#     obsp: 'connectivities', 'distances'

# %%
df["clusters"].unique().tolist()
# Out:
# ['non-cell',
#  'ventral animal',
#  'posterior ventraolateral margin',
#  'anterior ventrolateral margin',
#  'YSL',
#  'margin EVL',
#  'animal EVL',
#  'dorsal animal',
#  'miscellaneous',
#  'dorsal margin']

# %%
cells = ['non-cell',
 'ventral animal',
 'posterior ventraolateral margin',
 'anterior ventrolateral margin',
 'YSL',
 'margin EVL',
 'animal EVL',
 'dorsal animal',
 'miscellaneous',
 'dorsal margin']

['#e6194b',
 '#3cb44b',
 '#ffe119',
 '#4363d8',
 '#f58231',
 '#911eb4',
 '#42d4f4',
 '#f032e6',
 '#bfef45',
 '#fabed4',
 '#469990']
# Out:
# ['#e6194b',
#  '#3cb44b',
#  '#ffe119',
#  '#4363d8',
#  '#f58231',
#  '#911eb4',
#  '#42d4f4',
#  '#f032e6',
#  '#bfef45',
#  '#fabed4',
#  '#469990']

# %%
sc.pl.umap(p501, color="clusters")
# Out:
# /Users/kjenie/DataspellProjects/ptb_timepoints/.conda/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
p501.uns["leiden_colors"].tolist()
# Out:
# ['#e6194b',
#  '#3cb44b',
#  '#ffe119',
#  '#4363d8',
#  '#f58231',
#  '#911eb4',
#  '#42d4f4',
#  '#f032e6',
#  '#bfef45',
#  '#fabed4',
#  '#469990']

# %%
df
# Out:
#             ackr3b    acvr1ba      add3b       adka      ahi1     alcamb  \
# 3.0       0.000000   0.000000   0.000000   3.664631  3.664631   0.000000
# 18.0      0.000000   6.212582   7.100094  12.425164  3.550047   0.887512
# 47.0      2.466138  25.277914  28.977121  17.262966  5.548810   4.315741
# 58.0      1.469163  15.426214  33.790755  19.833704  9.549561   2.938327
# 194.0     0.663402  17.911853  26.536078  19.902058  5.970618   2.653608
# ...            ...        ...        ...        ...       ...        ...
# 23477.0  35.768927  12.624327  10.520273  25.248654  6.312164  18.936491
# 23478.0  28.581371  17.863357   9.527124  26.199591  2.381781  28.581371
# 23479.0  34.555895  33.173659  12.440122   8.293415  5.528943  23.498009
# 23480.0  21.318378  10.659189  14.212252  21.318378  0.000000  14.212252
# 23482.0  27.267002  17.351728   2.478818  19.830547  0.000000   4.957637
#
#              aplnra    aplnrb      hesx1  arl6ip5a  ...  global_sphere0  \
# ...

# %%
prefix = "50pe"

for col in tqdm(df.columns):
    data = {'key': f"{prefix}-{col}", 'value': json.dumps(df[col].to_list())}
    response = requests.post(url, json=data)
    print(response.json())
# Out:
#   0%|          | 1/521 [00:00<02:06,  4.12it/s]
# {'message': 'Data saved to Redis under key: 50pe-ackr3b'}
#   0%|          | 2/521 [00:00<02:14,  3.85it/s]
# {'message': 'Data saved to Redis under key: 50pe-acvr1ba'}
#   1%|          | 3/521 [00:00<02:14,  3.84it/s]
# {'message': 'Data saved to Redis under key: 50pe-add3b'}
#   1%|          | 4/521 [00:01<02:18,  3.73it/s]
# {'message': 'Data saved to Redis under key: 50pe-adka'}
#   1%|          | 5/521 [00:01<02:16,  3.77it/s]
# {'message': 'Data saved to Redis under key: 50pe-ahi1'}
#   1%|          | 6/521 [00:01<02:25,  3.53it/s]
# {'message': 'Data saved to Redis under key: 50pe-alcamb'}
#   1%|▏         | 7/521 [00:01<02:23,  3.57it/s]
# {'message': 'Data saved to Redis under key: 50pe-aplnra'}
#   2%|▏         | 9/521 [00:02<02:08,  3.99it/s]
# {'message': 'Data saved to Redis under key: 50pe-aplnrb'}
# {'message': 'Data saved to Redis under key: 50pe-hesx1'}
#   2%|▏         | 10/521 [00:02<02:10,  3.92it/s]
# ...

# %%
p501.var_names.tolist()
# Out:
# ['ackr3b',
#  'acvr1ba',
#  'add3b',
#  'adka',
#  'ahi1',
#  'alcamb',
#  'aplnra',
#  'aplnrb',
#  'hesx1',
#  'arl6ip5a',
#  'aspm',
#  'atf6',
#  'axin2',
#  'bambia',
#  'bhlha15',
#  'bmp2b',
#  'bmp7a',
#  'btg2',
#  'tbx3b',
#  'c1qbp',
#  'zmp:0000000624',
#  'ca9',
#  'casz1',
#  'cbx3a',
#  'cbx5',
#  'ccne2',
#  'ccng1',
#  'cd63',
#  'cdc14b',
#  'cdc42ep4a',
#  'cdca8',
#  'cdh1',
#  'cenpf',
#  'cfl1l',
#  'chst11',
#  'cldnd',
#  'clic4',
#  'clocka',
#  'cnn3a',
#  'crabp2b',
#  'creb3l2',
#  'cst3',
#  'cth1',
#  'cxcr4a',
#  'dact2',
#  'dharma',
#  'dkc1',
#  'dlgap5',
#  'dlx3b',
#  'dynll2b',
#  'efemp2b',
#  'efnb2b',
#  'egln1b',
#  'elavl3',
#  'emid1',
#  'emx3',
#  'epha2a',
#  'ephb3a',
#  'esrra',
#  'etv4',
#  'etv5a',
#  'eve1',
#  'f11r.1',
#  'lratd1',
#  'fbln2',
#  'zgc:175088',
#  'fgf8a',
#  'flrt3',
#  'fn1a',
#  'fn1b',
#  'fnbp1l',
#  'foxa2',
#  'foxa3',
#  'foxc1b',
#  'foxd3',
#  'foxn2b',
#  'foxp1b',
#  'fscn1a',
#  'fzd7b',
#  'fzd8a',
# ...

# %%
prefix = "50pe"

data = {'key': f"{prefix}-genes", 'value': json.dumps(p501.var_names.tolist())}
response = requests.post(url, json=data)
print(response.json())
# Out:
# {'message': 'Data saved to Redis under key: 50pe-genes'}

# %%
pal = {
    'non-cell': '#e6194b',
    'ventral animal': '#3cb44b',
    'posterior ventraolateral margin': '#ffe119',
    'anterior ventrolateral margin': '#4363d8',
    'YSL': '#f58231',
    'margin EVL': '#911eb4',
    'animal EVL': '#42d4f4',
    'dorsal animal': '#f032e6',
    'miscellaneous': '#bfef45',
    'dorsal margin': '#fabed4'
}

# %%
sc.pl.umap(p501, color="clusters", palette=pal)
# Out:
# /Users/kjenie/DataspellProjects/ptb_timepoints/.conda/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
prefix = "50pe"

data = {'key': f"{prefix}-clusters_pal", 'value': json.dumps(pal)}
response = requests.post(url, json=data)
print(response.json())
# Out:
# {'message': 'Data saved to Redis under key: 50pe-clusters_pal'}

# %%
p75 = sc.read("/Volumes/kresna-ssd/data/zebrafish/6som_and_imputed/23-08-29__scdata_75p_annotated__3dV7.h5ad")

# %%
adata = p75

# convert adata to df (normalized values)
# df = adata.to_df()

df = pd.DataFrame(adata.obsm["X_raw"], columns=adata.to_df().columns, index=adata.obs.index)

# add the obs in the df
df = pd.concat([df, adata.obs], axis=1)

# add the brain projection coordinates in the df
for x in range(adata.obsm["global_sphere"].shape[1]):
    df[f"global_sphere{x}"] = adata.obsm["global_sphere"][:,x]

# add the umap coordinates in the df
# iterate through all axis if there's more than 2, it accounts for it
for x in range(adata.obsm["X_umap"].shape[1]):
    df[f"X_umap{x}"] = adata.obsm["X_umap"][:,x]

normalize(df, "global_sphere", n_groups=adata.obsm["global_sphere"].shape[1])
normalize(df, "X_umap", n_groups=adata.obsm["X_umap"].shape[1])
# Out:
# 0
# 5937.1328805397325
# 5937.1328805397325
# 1
# 5451.546648489654
# 5937.1328805397325
# 2
# 5931.631294723227
# 5937.1328805397325
# global_sphere0
# 0
# 15.892268
# 15.892268
# 1
# 24.42374
# 24.42374
# X_umap1

# %%
df
# Out:
#            ackr3b   acvr1ba      add3b      adka      ahi1      alcamb  \
# 1.0      0.000000  0.979940   1.469909  2.449849  1.469909    0.000000
# 6.0      0.979175  1.958350  53.854631  9.791751  5.875051    0.000000
# 8.0      0.000000  0.000000  23.648953  5.518089  0.788298    0.788298
# 9.0      1.383253  1.383253  81.611907  8.299516  4.149758    2.766505
# 16.0     0.000000  2.718485  33.527985  7.249294  0.906162    5.436971
# ...           ...       ...        ...       ...       ...         ...
# 41350.0  0.000000  0.000000  40.310569  0.000000  0.000000  100.776423
# 41352.0  4.860444  1.215111   4.860444  0.000000  0.000000   61.970665
# 41353.0  4.418601  0.000000  10.604641  1.767440  0.000000   43.302285
# 41355.0  0.000000  0.000000  16.935912  0.000000  0.000000   67.743649
# 41356.0  4.544083  0.000000   4.544083  6.058777  0.000000   22.720413
#
#             aplnra    aplnrb     hesx1  arl6ip5a  ...  global_sphere0  \
# ...

# %%
p75.var_names.tolist()
# Out:
# ['ackr3b',
#  'acvr1ba',
#  'add3b',
#  'adka',
#  'ahi1',
#  'alcamb',
#  'aplnra',
#  'aplnrb',
#  'hesx1',
#  'arl6ip5a',
#  'aspm',
#  'atf6',
#  'axin2',
#  'bambia',
#  'bhlha15',
#  'bmp2b',
#  'bmp7a',
#  'btg2',
#  'tbx3b',
#  'c1qbp',
#  'zmp:0000000624',
#  'ca9',
#  'casz1',
#  'cbx3a',
#  'cbx5',
#  'ccne2',
#  'ccng1',
#  'cd63',
#  'cdc14b',
#  'cdc42ep4a',
#  'cdca8',
#  'cdh1',
#  'cenpf',
#  'cfl1l',
#  'chst11',
#  'cldnd',
#  'clic4',
#  'clocka',
#  'cnn3a',
#  'crabp2b',
#  'creb3l2',
#  'cst3',
#  'cth1',
#  'cxcr4a',
#  'dact2',
#  'dharma',
#  'dkc1',
#  'dlgap5',
#  'dlx3b',
#  'dynll2b',
#  'efemp2b',
#  'efnb2b',
#  'egln1b',
#  'elavl3',
#  'emid1',
#  'emx3',
#  'epha2a',
#  'ephb3a',
#  'esrra',
#  'etv4',
#  'etv5a',
#  'eve1',
#  'f11r.1',
#  'lratd1',
#  'fbln2',
#  'zgc:175088',
#  'fgf8a',
#  'flrt3',
#  'fn1a',
#  'fn1b',
#  'fnbp1l',
#  'foxa2',
#  'foxa3',
#  'foxc1b',
#  'foxd3',
#  'foxn2b',
#  'foxp1b',
#  'fscn1a',
#  'fzd7b',
#  'fzd8a',
# ...

# %%
p75.var_names.tolist()[90]
# Out:
# 'helb'

# %%
df
# Out:
#            ackr3b   acvr1ba      add3b      adka      ahi1      alcamb  \
# 1.0      0.000000  0.979940   1.469909  2.449849  1.469909    0.000000
# 6.0      0.979175  1.958350  53.854631  9.791751  5.875051    0.000000
# 8.0      0.000000  0.000000  23.648953  5.518089  0.788298    0.788298
# 9.0      1.383253  1.383253  81.611907  8.299516  4.149758    2.766505
# 16.0     0.000000  2.718485  33.527985  7.249294  0.906162    5.436971
# ...           ...       ...        ...       ...       ...         ...
# 41350.0  0.000000  0.000000  40.310569  0.000000  0.000000  100.776423
# 41352.0  4.860444  1.215111   4.860444  0.000000  0.000000   61.970665
# 41353.0  4.418601  0.000000  10.604641  1.767440  0.000000   43.302285
# 41355.0  0.000000  0.000000  16.935912  0.000000  0.000000   67.743649
# 41356.0  4.544083  0.000000   4.544083  6.058777  0.000000   22.720413
#
#             aplnra    aplnrb     hesx1  arl6ip5a  ...  global_sphere0  \
# ...

# %%
prefix = "75pe"

for col in tqdm(df.columns):
    data = {'key': f"{prefix}-{col}", 'value': json.dumps(df[col].to_list())}
    response = requests.post(url, json=data)
    print(response.json())
    
    # break
# Out:
#   0%|          | 1/515 [00:00<06:43,  1.27it/s]
# {'message': 'Data saved to Redis under key: 75pe-ackr3b'}
#   0%|          | 2/515 [00:01<06:43,  1.27it/s]
# {'message': 'Data saved to Redis under key: 75pe-acvr1ba'}
#   1%|          | 3/515 [00:02<06:52,  1.24it/s]
# {'message': 'Data saved to Redis under key: 75pe-add3b'}
#   1%|          | 4/515 [00:03<07:04,  1.20it/s]
# {'message': 'Data saved to Redis under key: 75pe-adka'}
#   1%|          | 5/515 [00:04<07:00,  1.21it/s]
# {'message': 'Data saved to Redis under key: 75pe-ahi1'}
#   1%|          | 6/515 [00:05<09:40,  1.14s/it]
# {'message': 'Data saved to Redis under key: 75pe-alcamb'}
#   1%|▏         | 7/515 [00:06<08:36,  1.02s/it]
# {'message': 'Data saved to Redis under key: 75pe-aplnra'}
#   2%|▏         | 8/515 [00:07<07:43,  1.09it/s]
# {'message': 'Data saved to Redis under key: 75pe-aplnrb'}
#   2%|▏         | 9/515 [00:08<07:27,  1.13it/s]
# {'message': 'Data saved to Redis under key: 75pe-hesx1'}
# ...

# %%
df["clusters"].unique().tolist()
# Out:
# ['YSL',
#  'tailbud',
#  'ectoderm ventral margin',
#  'marginal EVL',
#  'endoderm',
#  'heart mesoderm',
#  'ectoderm ventral posterior',
#  'animal EVL',
#  'ectoderm dorsal margin',
#  'somitic mesoderm',
#  'ectoderm lateral posterior',
#  'head mesoderm',
#  'ectoderm lateral anterior',
#  'ectoderm dorsal anterior',
#  'ectoderm ventral anterior',
#  'PGC',
#  'ectoderm dorsal posteror',
#  'notochord',
#  'DFC',
#  'pcp']

# %%
sc.pl.umap(p75, color="clusters")
# Out:
# /Users/kjenie/DataspellProjects/ptb_timepoints/.conda/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
# Using zip to combine the two lists into a dictionary
cell_color_dict = dict(zip(df["clusters"].unique().tolist(), p75.uns["clusters_colors"]))

# Display the dictionary
print(cell_color_dict)
# Out:
# {'YSL': '#1f77b4', 'tailbud': '#ff7f0e', 'ectoderm ventral margin': '#279e68', 'marginal EVL': '#d62728', 'endoderm': '#aa40fc', 'heart mesoderm': '#8c564b', 'ectoderm ventral posterior': '#e377c2', 'animal EVL': '#b5bd61', 'ectoderm dorsal margin': '#17becf', 'somitic mesoderm': '#aec7e8', 'ectoderm lateral posterior': '#ffbb78', 'head mesoderm': '#98df8a', 'ectoderm lateral anterior': '#ff9896', 'ectoderm dorsal anterior': '#c5b0d5', 'ectoderm ventral anterior': '#c49c94', 'PGC': '#f7b6d2', 'ectoderm dorsal posteror': '#dbdb8d', 'notochord': '#9edae5', 'DFC': '#ad494a', 'pcp': '#8c6d31'}

# %%
cell_color_dict
# Out:
# {'YSL': '#1f77b4',
#  'tailbud': '#ff7f0e',
#  'ectoderm ventral margin': '#279e68',
#  'marginal EVL': '#d62728',
#  'endoderm': '#aa40fc',
#  'heart mesoderm': '#8c564b',
#  'ectoderm ventral posterior': '#e377c2',
#  'animal EVL': '#b5bd61',
#  'ectoderm dorsal margin': '#17becf',
#  'somitic mesoderm': '#aec7e8',
#  'ectoderm lateral posterior': '#ffbb78',
#  'head mesoderm': '#98df8a',
#  'ectoderm lateral anterior': '#ff9896',
#  'ectoderm dorsal anterior': '#c5b0d5',
#  'ectoderm ventral anterior': '#c49c94',
#  'PGC': '#f7b6d2',
#  'ectoderm dorsal posteror': '#dbdb8d',
#  'notochord': '#9edae5',
#  'DFC': '#ad494a',
#  'pcp': '#8c6d31'}

# %%
url
# Out:
# 'https://fisheyes.techkyra.com/savedata'

# %%
prefix = "75pe"

data = {'key': f"{prefix}-clusters_pal", 'value': json.dumps(cell_color_dict)}
response = requests.post(url, json=data)
print(response.json())
# Out:
# {'message': 'Data saved to Redis under key: 75pe-clusters_pal'}

# %%
genes = p75.var_names.tolist()

# %%
prefix = "75pe"

data = {'key': f"{prefix}-genes", 'value': json.dumps(genes)}
response = requests.post(url, json=data)
print(response.json())
# Out:
# {'message': 'Data saved to Redis under key: 75pe-genes'}

# %%
sc.pl.umap(p75, color="clusters", palette=cell_color_dict)
# Out:
# /Users/kjenie/DataspellProjects/ptb_timepoints/.conda/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning:
#
# No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
p75.obs["clusters"].unique()
# Out:
# ['YSL', 'tailbud', 'ectoderm ventral margin', 'marginal EVL', 'endoderm', ..., 'PGC', 'ectoderm dorsal posteror', 'notochord', 'DFC', 'pcp']
# Length: 20
# Categories (20, object): ['DFC', 'PGC', 'YSL', 'animal EVL', ..., 'notochord', 'pcp', 'somitic mesoderm', 'tailbud']

# %%
p75.uns[]
# Out:
# ['#1f77b4',
#  '#ff7f0e',
#  '#279e68',
#  '#d62728',
#  '#aa40fc',
#  '#8c564b',
#  '#e377c2',
#  '#b5bd61',
#  '#17becf',
#  '#aec7e8',
#  '#ffbb78',
#  '#98df8a',
#  '#ff9896',
#  '#c5b0d5',
#  '#c49c94',
#  '#f7b6d2',
#  '#dbdb8d',
#  '#9edae5',
#  '#ad494a',
#  '#8c6d31']
